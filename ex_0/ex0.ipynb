# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Exercise 0
#
# We use this notebook for debugging and implementing the first exercise. Only the implemented methods and classes will be loaded and used here. Namely, no new implementation happens in the notebook itself.

# %%
from ex0 import ImageProcessor

# %%
image_processor = ImageProcessor(colour_type="RGB", image_path="./baboon.jpeg")

# %% [markdown]
# ## 1. Loading Image
#
# Just load the image using OpenCV.

# %%
print(image_processor._image.shape)
# Out:
# (454, 449, 3)

# %% [markdown]
# ## 2. Image Visualization
#
# Just visualize the image using matplotlib

# %%
image_processor.show_image()

# %% [markdown]
# ## 3. Image Saving

# %%
image_processor.save_image("./sample_saved.png")
image_processor_test = ImageProcessor(colour_type="Gray", image_path="./sample_saved.png")
print(image_processor_test._image.shape)
image_processor_test.show_image()
# Out:
# (454, 449)

# %% [markdown]
# ## 4. Image Conversion
# You should implement it using numpy's slicing properties not with opencv

# %%
image_processor.show_image()
image_processor.convert_colour()
image_processor.show_image()

# %%
image_processor.show_image()
image_processor.convert_colour()
image_processor.show_image()

# %% [markdown]
# ## 5. Image Clipping
#
# Clipping means making sure that all the pixel values have at least a min value and at most a max value.

# %%
image_processor.clip_image(0, 255)
image_processor.show_image()

# %% [markdown]
# ## 6. Grayscaling
#
# There are basically three methods for converting a color image into grayscale.
#
# - Lightness
# - Average
# - Luminosity

# %%
image_processor.convert_to_grayscale(method="luminosity")
image_processor.show_image()

# %% [markdown]
# ## 7. Rotation

# %%
image_processor.rotate_image(degrees=90)
image_processor.show_image()

# %%
image_processor.rotate_image(-90)
image_processor.show_image()

# %%
image_processor.flip_image(0)
image_processor.show_image()

# %%
image_processor.flip_image(0)
image_processor.show_image()

# %%
image_processor.flip_image(1)
image_processor.show_image()

# %%
image_processor.flip_image(1)
image_processor.show_image()

# %%
image_processor.flip_image(2)
image_processor.show_image()

# %%
image_processor.flip_image(2)
image_processor.show_image()

# %%
image_processor.crop_center(300, 100)
image_processor.show_image()

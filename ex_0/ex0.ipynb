# %%
from ex0 import ImageProcessor

processor = ImageProcessor(image_path="data/Image01.png", colour_type="RGB")
processor.show_image()

# %%
processor.convert_colour()
processor.save_image("output.png")
# Out:
# data/output.png

# %%
processor2 = ImageProcessor(image_path="data/output.png", colour_type="RGB")
processor2.show_image()

# %%
processor.rotate_image(270)
processor.show_image()

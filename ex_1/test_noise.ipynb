# %% [markdown]
# # 3. Artificial Noise

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from noise import (
    display_images, 
    load_image,
    add_gaussian_noise
)

# %%
image = load_image("./data/kitty.png")

# %% [markdown]
# ## 1.1 Gaussian Noise

# %%
noisy_gaussian = add_gaussian_noise(image=image, mean=0, sigma=25)
display_images(image, noisy_gaussian, title="Gaussian Noise")

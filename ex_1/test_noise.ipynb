# %% [markdown]
# # 3. Artificial Noise

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from noise import (
    display_images, 
    load_image,
    add_gaussian_noise,
    add_poisson_noise
)

# %%
image = load_image("./data/kitty.png")

# %% [markdown]
# ## 1.1. Gaussian Noise

# %%
noisy_gaussian = add_gaussian_noise(image=image, mean=10, sigma=80)
display_images(image, noisy_gaussian, title="Gaussian Noise")

# %% [markdown]
# ## 1.2. Poisson Noise

# %%
noisy_poisson = add_poisson_noise(image=image)
display_images(image, noisy_poisson, title="Poisson Noise")

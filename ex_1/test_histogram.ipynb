# %% [markdown]
# # 2. Histogram Equalization

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from histogram_equalization import (
    compute_histogram, 
    load_image,
    compute_cdf,
    equalize_image
)
from utils.utils import show_image, show_histogram, show_cdf

# %% [markdown]
# ## 1.1. Histogram Calculation

# %%
image = load_image(path="./data/hello.png")
print(image.shape)
histogram = compute_histogram(image=image)
# Out:
# (632, 689)

# %%
show_image(image, "Hello Image")

# %%
show_histogram(histogram=histogram)

# %% [markdown]
# ## 1.2. CDF Calculation

# %%
cdf = compute_cdf(histogram)
show_cdf(cdf)
# Out:
# 435448

# %% [markdown]
# ## 1.3. Image Equalization

# %%
new_image = equalize_image(image, cdf)
show_image(new_image, "New Image")

# %%
new_histogram = compute_histogram(new_image)
new_cdf = compute_cdf(new_histogram)
# Out:
# 435448

# %%
show_histogram(new_histogram)

# %%
show_cdf(new_cdf)

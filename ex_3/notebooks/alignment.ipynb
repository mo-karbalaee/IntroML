# %%
import os
import sys

ROOT = os.path.abspath("..")  
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from kaktovikAlignmentSimple import _binarize, simpleAlignment
import cv2
from IPython.display import display

from PIL import Image

# %%
img = cv2.imread("../img/kaktovik-012_rot_0.jpg", cv2.IMREAD_GRAYSCALE)
binarized = _binarize(img)
print(binarized.min(), binarized.max())
# Out:
# 0 255

# %%
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=L size=155x134>

# %%
aligned = simpleAlignment(img, 256)

# %%
display(Image.fromarray(aligned))
# Out:
# <PIL.Image.Image image mode=L size=256x256>
